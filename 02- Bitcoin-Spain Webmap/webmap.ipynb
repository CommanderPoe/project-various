# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
# Dedicated library
# add to final script
import folium

# %%
# Inspecting library
dir(folium)
help(folium)
# Out:
# ['Choropleth',
#  'Circle',
#  'CircleMarker',
#  'ClickForMarker',
#  'ColorLine',
#  'ColorMap',
#  'CssLink',
#  'CustomIcon',
#  'Div',
#  'DivIcon',
#  'Element',
#  'FeatureGroup',
#  'Figure',
#  'FitBounds',
#  'GeoJson',
#  'GeoJsonPopup',
#  'GeoJsonTooltip',
#  'Html',
#  'IFrame',
#  'Icon',
#  'JavascriptLink',
#  'LatLngPopup',
#  'LayerControl',
#  'LinearColormap',
#  'Link',
#  'MacroElement',
#  'Map',
#  'Marker',
#  'PolyLine',
#  'Polygon',
#  'Popup',
#  'Rectangle',
#  'RegularPolygonMarker',
#  'StepColormap',
#  'TileLayer',
#  'Tooltip',
#  'TopoJson',
#  'Vega',
#  'VegaLite',
#  'WmsTileLayer',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_version',
#  'branca',
#  'elements',
#  'features',
#  'folium',
#  'map',
#  'raster_layers',
#  'sys',
#  'utilities',
#  'vector_layers']

# %% [markdown]
# <br/>

# %% [markdown]
# ---

# %%
# Scraping bitnodes
from bs4 import BeautifulSoup
import requests
import regex as re

# %%
# Testing first page
url = 'https://bitnodes.io/nodes/?q=Spain'

# %%
# checking response of the website
response = requests.get(url)
response.status_code
# Out:
# 200

# %%
# parsing the website (only single page) 
soup = BeautifulSoup(response.content, "html.parser")

# %%
# selecting table with info and printing results
table = soup.select('body > div.container > div:nth-child(10) > div > table > tr')

for i in table:
    print(i.get_text())
# Out:
# NODE
# ADDRESS
# USER AGENT
# HEIGHT
# LOCATION
# NETWORK
#
#
#
# 188.127.182.204:8333
#
# Since 6 minutes ago
# /Satoshi:0.21.1(FutureBit-Apollo-Node)/
# NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709737
# Madrid, Spain
# Europe/Madrid
#
# Xtra Telecom S.A.
# AS15704
#
# 188.127.182.204:8333Since 6 minutes ago
# /Satoshi:0.21.1(FutureBit-Apollo-Node)/ (70016)NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709737
# Madrid, SpainEurope/Madrid
# Xtra Telecom S.A.AS15704
#
#
#
# 83.39.95.241:8333
# 241.red-83-39-95.dynamicip.rima-tde.net
#
# Since 6 minutes ago
# /Satoshi:22.0.0/
# NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709736
# Madrid, Spain
# Europe/Madrid
#
# Telefonica De Espana
# AS3352
#
# 83.39.95.241:8333241.red-83-39-95.dynamicip.rima-tde.netSince 6 minutes ago
# /Satoshi:22.0.0/ (70016)NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709736
# Madrid, SpainEurope/Madrid
# Telefonica De EspanaAS3352
#
#
#
# 46.26.88.52:8333
# static-52-88-26-46.ipcom.comunitel.net
#
# Since 28 minutes ago
# /Satoshi:0.21.1/
# NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709736
# Sueca, Spain
# Europe/Madrid
#
# Vodafone Spain
# AS12430
#
# 46.26.88.52:8333static-52-88-26-46.ipcom.comunitel.netSince 28 minutes ago
# /Satoshi:0.21.1/ (70016)NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709736
# Sueca, SpainEurope/Madrid
# Vodafone SpainAS12430
#
#
#
# 176.85.239.251:8333
# 251.red-176-85-239.dynamicip.rima-tde.net
#
# Since 50 minutes ago
# /Satoshi:22.0.0/
# NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709736
# Boceguillas, Spain
# Europe/Madrid
#
# Telefonica De Espana
# AS3352
#
# 176.85.239.251:8333251.red-176-85-239.dynamicip.rima-tde.netSince 50 minutes ago
# /Satoshi:22.0.0/ (70016)NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709736
# Boceguillas, SpainEurope/Madrid
# Telefonica De EspanaAS3352
#
#
#
# 185.153.165.202:8333
#
# Since an hour ago
# /Satoshi:0.21.0/
# NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709737
# Málaga, Spain
# Europe/Madrid
#
# Xtra Telecom S.A.
# AS15704
#
# 185.153.165.202:8333Since an hour ago
# /Satoshi:0.21.0/ (70016)NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709737
# Málaga, SpainEurope/Madrid
# Xtra Telecom S.A.AS15704
#
#
#
# 78.30.32.73:8333
# static.masmovil.com
#
# Since 2 hours ago
# /Satoshi:22.0.0/
# NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709736
# Aguadulce, Spain
# Europe/Madrid
#
# Xtra Telecom S.A.
# AS15704
#
# 78.30.32.73:8333static.masmovil.comSince 2 hours ago
# /Satoshi:22.0.0/ (70016)NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709736
# Aguadulce, SpainEurope/Madrid
# Xtra Telecom S.A.AS15704
#
#
#
# 81.61.40.199:8333
# 81.61.40.199.dyn.user.ono.com
#
# Since 3 hours ago
# /Satoshi:22.0.0/
# NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709737
# Madrid, Spain
# Europe/Madrid
#
# Vodafone Ono, S.A.
# AS6739
#
# 81.61.40.199:833381.61.40.199.dyn.user.ono.comSince 3 hours ago
# /Satoshi:22.0.0/ (70016)NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709737
# Madrid, SpainEurope/Madrid
# Vodafone Ono, S.A.AS6739
#
#
#
# 2.153.80.222:8333
# 2.153.80.222.dyn.user.ono.com
#
# Since 3 hours ago
# /Satoshi:22.0.0/
# NODE_NETWORK, NODE_BLOOM, NODE_WITNESS, NODE_NETWORK_LIMITED, NODE_COMPACT_FILTERS (1101)
# 709736
# Madrid, Spain
# Europe/Madrid
#
# Vodafone Spain
# AS12430
#
# 2.153.80.222:83332.153.80.222.dyn.user.ono.comSince 3 hours ago
# /Satoshi:22.0.0/ (70016)NODE_NETWORK, NODE_BLOOM, NODE_WITNESS, NODE_NETWORK_LIMITED, NODE_COMPACT_FILTERS (1101)
# 709736
# Madrid, SpainEurope/Madrid
# Vodafone SpainAS12430
#
#
#
# 89.6.69.22:8333
# static-22-69-6-89.ipcom.comunitel.net
#
# Since 4 hours ago
# /Satoshi:0.19.1/
# NODE_WITNESS, NODE_NETWORK_LIMITED (1032)
# 709736
# Viladecans, Spain
# Europe/Madrid
#
# Vodafone Spain
# AS12430
#
# 89.6.69.22:8333static-22-69-6-89.ipcom.comunitel.netSince 4 hours ago
# /Satoshi:0.19.1/ (70015)NODE_WITNESS, NODE_NETWORK_LIMITED (1032)
# 709736
# Viladecans, SpainEurope/Madrid
# Vodafone SpainAS12430
#
#
#
# 79.158.152.164:8333
# 164.red-79-158-152.dynamicip.rima-tde.net
#
# Since 4 hours ago
# /Satoshi:22.0.0/
# NODE_WITNESS, NODE_NETWORK_LIMITED (1032)
# 709736
# Vigo, Spain
# Europe/Madrid
#
# Telefonica De Espana
# AS3352
#
# 79.158.152.164:8333164.red-79-158-152.dynamicip.rima-tde.netSince 4 hours ago
# /Satoshi:22.0.0/ (70016)NODE_WITNESS, NODE_NETWORK_LIMITED (1032)
# 709736
# Vigo, SpainEurope/Madrid
# Telefonica De EspanaAS3352
#
#
#
# 93.176.171.227:8333
# static.masmovil.com
#
# Since 5 hours ago
# /Satoshi:0.21.1/
# NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709737
# Lleida, Spain
# Europe/Madrid
#
# Xtra Telecom S.A.
# AS15704
#
# 93.176.171.227:8333static.masmovil.comSince 5 hours ago
# /Satoshi:0.21.1/ (70016)NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709737
# Lleida, SpainEurope/Madrid
# Xtra Telecom S.A.AS15704
#
#
#
# 46.6.8.24:8333
#
# Since 5 hours ago
# /Satoshi:22.0.0/
# NODE_NETWORK, NODE_BLOOM, NODE_WITNESS, NODE_NETWORK_LIMITED, NODE_COMPACT_FILTERS (1101)
# 709737
# Usagre, Spain
# Europe/Madrid
#
# Xtra Telecom S.A.
# AS15704
#
# 46.6.8.24:8333Since 5 hours ago
# /Satoshi:22.0.0/ (70016)NODE_NETWORK, NODE_BLOOM, NODE_WITNESS, NODE_NETWORK_LIMITED, NODE_COMPACT_FILTERS (1101)
# 709737
# Usagre, SpainEurope/Madrid
# Xtra Telecom S.A.AS15704
#
#
#
# 87.218.217.13:8333
# 13.217.218.87.dynamic.jazztel.es
#
# Since 5 hours ago
# /Satoshi:0.21.1/
# NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709736
# Torres de la Alameda, Spain
# Europe/Madrid
#
# Orange Espagne SA
# AS12479
#
# 87.218.217.13:833313.217.218.87.dynamic.jazztel.esSince 5 hours ago
# /Satoshi:0.21.1/ (70016)NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709736
# Torres de la Alameda, SpainEurope/Madrid
# Orange Espagne SAAS12479
#
#
#
# 88.12.102.11:8333
# 11.red-88-12-102.dynamicip.rima-tde.net
#
# Since 5 hours ago
# /Satoshi:22.0.0/
# NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709736
# Albacete, Spain
# Europe/Madrid
#
# Telefonica De Espana
# AS3352
#
# 88.12.102.11:833311.red-88-12-102.dynamicip.rima-tde.netSince 5 hours ago
# /Satoshi:22.0.0/ (70016)NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709736
# Albacete, SpainEurope/Madrid
# Telefonica De EspanaAS3352
#
#
#
# 213.195.113.240:8333
#
# Since 5 hours ago
# /Satoshi:22.0.0/
# NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709737
# Barcelona, Spain
# Europe/Madrid
#
# Xtra Telecom S.A.
# AS15704
#
# 213.195.113.240:8333Since 5 hours ago
# /Satoshi:22.0.0/ (70016)NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709737
# Barcelona, SpainEurope/Madrid
# Xtra Telecom S.A.AS15704
#
#
#
# 109.205.134.28:8333
# 28.pool109-205-134.dynamic.orange.es
#
# Since 5 hours ago
# /Satoshi:0.21.1/
# NODE_WITNESS, NODE_NETWORK_LIMITED (1032)
# 709737
# Madrid, Spain
# Europe/Madrid
#
# Orange Espagne SA
# AS12479
#
# 109.205.134.28:833328.pool109-205-134.dynamic.orange.esSince 5 hours ago
# /Satoshi:0.21.1/ (70016)NODE_WITNESS, NODE_NETWORK_LIMITED (1032)
# 709737
# Madrid, SpainEurope/Madrid
# Orange Espagne SAAS12479
#
#
#
# 92.59.209.151:8333
#
# Since 7 hours ago
# /Satoshi:22.0.0/
# NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709736
# Armilla, Spain
# Europe/Madrid
#
# Orange Espagne SA
# AS12479
#
# 92.59.209.151:8333Since 7 hours ago
# /Satoshi:22.0.0/ (70016)NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709736
# Armilla, SpainEurope/Madrid
# Orange Espagne SAAS12479
#
#
#
# 77.226.217.179:8333
# static-179-217-226-77.ipcom.comunitel.net
#
# Since 8 hours ago
# /Satoshi:0.21.1/
# NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709737
# Barcelona, Spain
# Europe/Madrid
#
# Vodafone Spain
# AS12430
#
# 77.226.217.179:8333static-179-217-226-77.ipcom.comunitel.netSince 8 hours ago
# /Satoshi:0.21.1/ (70016)NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709737
# Barcelona, SpainEurope/Madrid
# Vodafone SpainAS12430
#
#
#
# 46.253.226.179:8333
#
# Since 10 hours ago
# /Satoshi:22.0.0/
# NODE_WITNESS, NODE_NETWORK_LIMITED (1032)
# 709736
# Baena, Spain
# Europe/Madrid
#
# Tvb Teledistribucion S.l.
# AS56345
#
# 46.253.226.179:8333Since 10 hours ago
# /Satoshi:22.0.0/ (70016)NODE_WITNESS, NODE_NETWORK_LIMITED (1032)
# 709736
# Baena, SpainEurope/Madrid
# Tvb Teledistribucion S.l.AS56345
#
#
#
# 81.61.73.125:8333
# 81.61.73.125.dyn.user.ono.com
#
# Since 10 hours ago
# /Satoshi:22.0.0/
# NODE_NETWORK, NODE_BLOOM, NODE_WITNESS, NODE_NETWORK_LIMITED (1037)
# 709736
# Las Palmas de Gran Canaria, Spain
# Atlantic/Canary
#
# Vodafone Ono, S.A.
# AS6739
#
# 81.61.73.125:833381.61.73.125.dyn.user.ono.comSince 10 hours ago
# /Satoshi:22.0.0/ (70016)NODE_NETWORK, NODE_BLOOM, NODE_WITNESS, NODE_NETWORK_LIMITED (1037)
# 709736
# Las Palmas de Gran Canaria, SpainAtlantic/Canary
# Vodafone Ono, S.A.AS6739
#
#
#
# 2.137.33.199:8333
# 199.red-2-137-33.dynamicip.rima-tde.net
#
# Since 14 hours ago
# /Satoshi:22.0.0/
# NODE_NETWORK, NODE_BLOOM, NODE_WITNESS, NODE_NETWORK_LIMITED (1037)
# 709737
# Madrid, Spain
# Europe/Madrid
#
# Telefonica De Espana
# AS3352
#
# 2.137.33.199:8333199.red-2-137-33.dynamicip.rima-tde.netSince 14 hours ago
# /Satoshi:22.0.0/ (70016)NODE_NETWORK, NODE_BLOOM, NODE_WITNESS, NODE_NETWORK_LIMITED (1037)
# 709737
# Madrid, SpainEurope/Madrid
# Telefonica De EspanaAS3352
#
#
#
# [2a0c:5a80:1a12:0:910f:614:f8f:1165]:8333
#
# Since 16 hours ago
# /Satoshi:22.0.0/
# NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709736
# Madrid, Spain
# Europe/Madrid
#
# Digi Spain Telecom S.l.u.
# AS57269
#
# [2a0c:5a80:1a12:0:910f:614:f8f:1165]:8333Since 16 hours ago
# /Satoshi:22.0.0/ (70016)NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709736
# Madrid, SpainEurope/Madrid
# Digi Spain Telecom S.l.u.AS57269
#
#
#
# [2a0c:5a80:1e08:a000:a494:3ead:bf5e:d520]:8333
#
# Since 17 hours ago
# /Satoshi:0.21.0/
# NODE_WITNESS, NODE_NETWORK_LIMITED (1032)
# 709737
# Madrid, Spain
# Europe/Madrid
#
# Digi Spain Telecom S.l.u.
# AS57269
#
# [2a0c:5a80:1e08:a000:a494:3ead:bf5e:d520]:8333Since 17 hours ago
# /Satoshi:0.21.0/ (70016)NODE_WITNESS, NODE_NETWORK_LIMITED (1032)
# 709737
# Madrid, SpainEurope/Madrid
# Digi Spain Telecom S.l.u.AS57269
#
#
#
# 83.55.54.179:8333
# 179.red-83-55-54.dynamicip.rima-tde.net
#
# Since 19 hours ago
# /Satoshi:0.21.1/
# NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709736
# Chauchina, Spain
# Europe/Madrid
#
# Telefonica De Espana
# AS3352
#
# 83.55.54.179:8333179.red-83-55-54.dynamicip.rima-tde.netSince 19 hours ago
# /Satoshi:0.21.1/ (70016)NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709736
# Chauchina, SpainEurope/Madrid
# Telefonica De EspanaAS3352
#
#
#
# 83.39.37.207:8333
# 207.red-83-39-37.dynamicip.rima-tde.net
#
# Since 19 hours ago
# /Satoshi:22.0.0/
# NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709736
# Cáceres, Spain
# Europe/Madrid
#
# Telefonica De Espana
# AS3352
#
# 83.39.37.207:8333207.red-83-39-37.dynamicip.rima-tde.netSince 19 hours ago
# /Satoshi:22.0.0/ (70016)NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709736
# Cáceres, SpainEurope/Madrid
# Telefonica De EspanaAS3352
#
#
#
# 90.162.126.41:8333
#
# Since 20 hours ago
# /Satoshi:22.0.0/
# NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709736
# Valladolid, Spain
# Europe/Madrid
#
# Orange Espagne SA
# AS12479
#
# 90.162.126.41:8333Since 20 hours ago
# /Satoshi:22.0.0/ (70016)NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709736
# Valladolid, SpainEurope/Madrid
# Orange Espagne SAAS12479
#
#
#
# 83.39.94.29:8333
# 29.red-83-39-94.dynamicip.rima-tde.net
#
# Since 1 day ago
# /Satoshi:22.0.0/
# NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709736
# Madrid, Spain
# Europe/Madrid
#
# Telefonica De Espana
# AS3352
#
# 83.39.94.29:833329.red-83-39-94.dynamicip.rima-tde.netSince 1 day ago
# /Satoshi:22.0.0/ (70016)NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709736
# Madrid, SpainEurope/Madrid
# Telefonica De EspanaAS3352
#
#
#
# 88.1.136.102:8333
# 102.red-88-1-136.dynamicip.rima-tde.net
#
# Since 1 day, 1 hour ago
# /Satoshi:0.21.2/
# NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709737
# Tres Cantos, Spain
# Europe/Madrid
#
# Telefonica De Espana
# AS3352
#
# 88.1.136.102:8333102.red-88-1-136.dynamicip.rima-tde.netSince 1 day, 1 hour ago
# /Satoshi:0.21.2/ (70016)NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709737
# Tres Cantos, SpainEurope/Madrid
# Telefonica De EspanaAS3352
#
#
#
# 144.178.135.74:8333
# static.masmovil.com
#
# Since 1 day, 1 hour ago
# /Satoshi:22.0.0/
# NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709736
# San Fulgencio, Spain
# Europe/Madrid
#
# Xtra Telecom S.A.
# AS15704
#
# 144.178.135.74:8333static.masmovil.comSince 1 day, 1 hour ago
# /Satoshi:22.0.0/ (70016)NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709736
# San Fulgencio, SpainEurope/Madrid
# Xtra Telecom S.A.AS15704
#
#
#
# 37.15.63.3:8333
# 3.63.15.37.dynamic.jazztel.es
#
# Since 1 day, 7 hours ago
# /Satoshi:0.21.1/
# NODE_NETWORK, NODE_BLOOM, NODE_WITNESS, NODE_NETWORK_LIMITED (1037)
# 709736
# Sant Cugat del Vallès, Spain
# Europe/Madrid
#
# Orange Espagne SA
# AS12479
#
# 37.15.63.3:83333.63.15.37.dynamic.jazztel.esSince 1 day, 7 hours ago
# /Satoshi:0.21.1/ (70016)NODE_NETWORK, NODE_BLOOM, NODE_WITNESS, NODE_NETWORK_LIMITED (1037)
# 709736
# Sant Cugat del Vallès, SpainEurope/Madrid
# Orange Espagne SAAS12479
#
#
#
# 83.58.154.203:8333
# 203.red-83-58-154.dynamicip.rima-tde.net
#
# Since 1 day, 12 hours ago
# /Satoshi:22.0.0/
# NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709736
# Las Palmas de Gran Canaria, Spain
# Atlantic/Canary
#
# Telefonica De Espana
# AS3352
#
# 83.58.154.203:8333203.red-83-58-154.dynamicip.rima-tde.netSince 1 day, 12 hours ago
# /Satoshi:22.0.0/ (70016)NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709736
# Las Palmas de Gran Canaria, SpainAtlantic/Canary
# Telefonica De EspanaAS3352
#
#
#
# 81.184.215.161:8333
# 81.184.215.161.dyn.user.ono.com
#
# Since 1 day, 14 hours ago
# /Satoshi:0.21.1/
# NODE_WITNESS, NODE_NETWORK_LIMITED (1032)
# 709737
# Pamplona, Spain
# Europe/Madrid
#
# Vodafone Ono, S.A.
# AS6739
#
# 81.184.215.161:833381.184.215.161.dyn.user.ono.comSince 1 day, 14 hours ago
# /Satoshi:0.21.1/ (70016)NODE_WITNESS, NODE_NETWORK_LIMITED (1032)
# 709737
# Pamplona, SpainEurope/Madrid
# Vodafone Ono, S.A.AS6739
#
#
#
# 90.163.172.139:8333
#
# Since 1 day, 19 hours ago
# /Satoshi:0.21.1/
# NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709736
# Murcia, Spain
# Europe/Madrid
#
# Orange Espagne SA
# AS12479
#
# 90.163.172.139:8333Since 1 day, 19 hours ago
# /Satoshi:0.21.1/ (70016)NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709736
# Murcia, SpainEurope/Madrid
# Orange Espagne SAAS12479
#
#
#
# 146.158.193.203:8333
# sergioir.ddns.jazztel.es
#
# Since 2 days, 3 hours ago
# /Satoshi:0.21.1/
# NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709737
# Madrid, Spain
# Europe/Madrid
#
# Orange Espagne SA
# AS12479
#
# 146.158.193.203:8333sergioir.ddns.jazztel.esSince 2 days, 3 hours ago
# /Satoshi:0.21.1/ (70016)NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709737
# Madrid, SpainEurope/Madrid
# Orange Espagne SAAS12479
#
#
#
# 89.35.142.168:8333
#
# Since 2 days, 5 hours ago
# /Satoshi:0.21.1/
# NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709736
# Cordova, Spain
# Europe/Madrid
#
# Procono S.A.
# AS34977
#
# 89.35.142.168:8333Since 2 days, 5 hours ago
# /Satoshi:0.21.1/ (70016)NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709736
# Cordova, SpainEurope/Madrid
# Procono S.A.AS34977
#
#
#
# 93.176.161.169:8333
# static.masmovil.com
#
# Since 2 days, 11 hours ago
# /Satoshi:22.0.0/
# NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709737
# Barcelona, Spain
# Europe/Madrid
#
# Xtra Telecom S.A.
# AS15704
#
# 93.176.161.169:8333static.masmovil.comSince 2 days, 11 hours ago
# /Satoshi:22.0.0/ (70016)NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709737
# Barcelona, SpainEurope/Madrid
# Xtra Telecom S.A.AS15704
#
#
#
# 212.14.101.8:8333
# static.8.101.14.212.ibercom.com
#
# Since 2 days, 11 hours ago
# /Satoshi:0.21.1/
# NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709737
# Bilbao, Spain
# Europe/Madrid
#
# Xtra Telecom S.A.
# AS15704
#
# 212.14.101.8:8333static.8.101.14.212.ibercom.comSince 2 days, 11 hours ago
# /Satoshi:0.21.1/ (70016)NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709737
# Bilbao, SpainEurope/Madrid
# Xtra Telecom S.A.AS15704
#
#
#
# 62.83.157.147:8333
# 62.83.157.147.dyn.user.ono.com
#
# Since 3 days, 1 hour ago
# /Satoshi:0.20.1/
# NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709737
# Marbella, Spain
# Europe/Madrid
#
# Vodafone Spain
# AS12430
#
# 62.83.157.147:833362.83.157.147.dyn.user.ono.comSince 3 days, 1 hour ago
# /Satoshi:0.20.1/ (70015)NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709737
# Marbella, SpainEurope/Madrid
# Vodafone SpainAS12430
#
#
#
# 81.40.210.166:8333
# 166.red-81-40-210.staticip.rima-tde.net
#
# Since 3 days, 4 hours ago
# /Satoshi:22.0.0/
# NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709736
# Madrid, Spain
# Europe/Madrid
#
# Telefonica De Espana
# AS3352
#
# 81.40.210.166:8333166.red-81-40-210.staticip.rima-tde.netSince 3 days, 4 hours ago
# /Satoshi:22.0.0/ (70016)NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709736
# Madrid, SpainEurope/Madrid
# Telefonica De EspanaAS3352
#
#
#
# 2.138.74.205:8333
# 205.red-2-138-74.dynamicip.rima-tde.net
#
# Since 3 days, 6 hours ago
# /Satoshi:0.21.1/
# NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709736
# Tacoronte, Spain
# Atlantic/Canary
#
# Telefonica De Espana
# AS3352
#
# 2.138.74.205:8333205.red-2-138-74.dynamicip.rima-tde.netSince 3 days, 6 hours ago
# /Satoshi:0.21.1/ (70016)NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709736
# Tacoronte, SpainAtlantic/Canary
# Telefonica De EspanaAS3352
#
#
#
# 87.222.235.33:8333
# 33.235.222.87.dynamic.jazztel.es
#
# Since 3 days, 7 hours ago
# /Satoshi:0.21.1(FutureBit-Apollo-Node)/
# NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709737
# Candas, Spain
# Europe/Madrid
#
# Orange Espagne SA
# AS12479
#
# 87.222.235.33:833333.235.222.87.dynamic.jazztel.esSince 3 days, 7 hours ago
# /Satoshi:0.21.1(FutureBit-Apollo-Node)/ (70016)NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709737
# Candas, SpainEurope/Madrid
# Orange Espagne SAAS12479
#
#
#
# 81.184.168.238:8333
# 81.184.168.238.dyn.user.ono.com
#
# Since 3 days, 7 hours ago
# /Satoshi:0.21.1/
# NODE_WITNESS, NODE_NETWORK_LIMITED (1032)
# 709736
# Atarrabia, Spain
# Europe/Madrid
#
# Vodafone Ono, S.A.
# AS6739
#
# 81.184.168.238:833381.184.168.238.dyn.user.ono.comSince 3 days, 7 hours ago
# /Satoshi:0.21.1/ (70016)NODE_WITNESS, NODE_NETWORK_LIMITED (1032)
# 709736
# Atarrabia, SpainEurope/Madrid
# Vodafone Ono, S.A.AS6739
#
#
#
# 2.152.78.124:8333
# 2.152.78.124.dyn.user.ono.com
#
# Since 3 days, 20 hours ago
# /Satoshi:22.0.0/
# NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709736
# Barcelona, Spain
# Europe/Madrid
#
# Vodafone Ono, S.A.
# AS6739
#
# 2.152.78.124:83332.152.78.124.dyn.user.ono.comSince 3 days, 20 hours ago
# /Satoshi:22.0.0/ (70016)NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709736
# Barcelona, SpainEurope/Madrid
# Vodafone Ono, S.A.AS6739
#
#
#
# 83.33.232.62:8333
# 62.red-83-33-232.dynamicip.rima-tde.net
#
# Since 3 days, 21 hours ago
# /Satoshi:0.20.0/
# NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709737
# Las Rozas de Madrid, Spain
# Europe/Madrid
#
# Telefonica De Espana
# AS3352
#
# 83.33.232.62:833362.red-83-33-232.dynamicip.rima-tde.netSince 3 days, 21 hours ago
# /Satoshi:0.20.0/ (70015)NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709737
# Las Rozas de Madrid, SpainEurope/Madrid
# Telefonica De EspanaAS3352
#
#
#
# 84.39.176.10:8333
# static.masmovil.com
#
# Since 3 days, 22 hours ago
# /Satoshi:0.21.1/
# NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709736
# Amorebieta, Spain
# Europe/Madrid
#
# Xtra Telecom S.A.
# AS15704
#
# 84.39.176.10:8333static.masmovil.comSince 3 days, 22 hours ago
# /Satoshi:0.21.1/ (70016)NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709736
# Amorebieta, SpainEurope/Madrid
# Xtra Telecom S.A.AS15704
#
#
#
# 2.138.174.158:8333
# 158.red-2-138-174.dynamicip.rima-tde.net
#
# Since 4 days, 4 hours ago
# /Satoshi:22.0.0/
# NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709737
# Pamplona, Spain
# Europe/Madrid
#
# Telefonica De Espana
# AS3352
#
# 2.138.174.158:8333158.red-2-138-174.dynamicip.rima-tde.netSince 4 days, 4 hours ago
# /Satoshi:22.0.0/ (70016)NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709737
# Pamplona, SpainEurope/Madrid
# Telefonica De EspanaAS3352
#
#
#
# 90.170.20.2:8333
#
# Since 4 days, 5 hours ago
# /Satoshi:0.21.1/
# NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709737
# Les Borges Blanques, Spain
# Europe/Madrid
#
# Orange Espagne SA
# AS12479
#
# 90.170.20.2:8333Since 4 days, 5 hours ago
# /Satoshi:0.21.1/ (70016)NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709737
# Les Borges Blanques, SpainEurope/Madrid
# Orange Espagne SAAS12479
#
#
#
# 88.12.34.111:8333
# 111.red-88-12-34.staticip.rima-tde.net
#
# Since 4 days, 6 hours ago
# /Satoshi:0.21.1/
# NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709736
# Madrid, Spain
# Europe/Madrid
#
# Telefonica De Espana
# AS3352
#
# 88.12.34.111:8333111.red-88-12-34.staticip.rima-tde.netSince 4 days, 6 hours ago
# /Satoshi:0.21.1/ (70016)NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709736
# Madrid, SpainEurope/Madrid
# Telefonica De EspanaAS3352
#
#
#
# 46.6.10.230:8333
#
# Since 4 days, 8 hours ago
# /Satoshi:22.0.0/
# NODE_NETWORK, NODE_BLOOM, NODE_WITNESS, NODE_NETWORK_LIMITED (1037)
# 709736
# Arcos de Jalon, Spain
# Europe/Madrid
#
# Xtra Telecom S.A.
# AS15704
#
# 46.6.10.230:8333Since 4 days, 8 hours ago
# /Satoshi:22.0.0/ (70016)NODE_NETWORK, NODE_BLOOM, NODE_WITNESS, NODE_NETWORK_LIMITED (1037)
# 709736
# Arcos de Jalon, SpainEurope/Madrid
# Xtra Telecom S.A.AS15704
#
#
#
# 85.58.120.201:8333
# 201.pool85-58-120.static.orange.es
#
# Since 4 days, 9 hours ago
# /Satoshi:22.0.0/
# NODE_NETWORK, NODE_BLOOM, NODE_WITNESS, NODE_NETWORK_LIMITED, NODE_COMPACT_FILTERS (1101)
# 709737
# Casabermeja, Spain
# Europe/Madrid
#
# Orange Espagne SA
# AS12479
#
# 85.58.120.201:8333201.pool85-58-120.static.orange.esSince 4 days, 9 hours ago
# /Satoshi:22.0.0/ (70016)NODE_NETWORK, NODE_BLOOM, NODE_WITNESS, NODE_NETWORK_LIMITED, NODE_COMPACT_FILTERS (1101)
# 709737
# Casabermeja, SpainEurope/Madrid
# Orange Espagne SAAS12479

# %%
def ext_info()

# %%
# Saving text in an empty list
text = [] 

for i in table: 
    text.append(i.get_text())

# %%
# Headers
headers = text[0].split('\n')[2:-1] 
headers = [item.lower().replace(' ','_') for item in headers]

# %%
headers
# Out:
# ['address', 'user_agent', 'height', 'location', 'network']

# %%
# Ip addresses
address = []


for n in range(1,len(text)):
    #if end_ip in text[n][2:17]
    address.append(re.findall('[\d[.]+', text[n])[0])

# %%
address
len(address)
# Out:
# ['188.127.182.204',
#  '83.39.95.241',
#  '46.26.88.52',
#  '176.85.239.251',
#  '185.153.165.202',
#  '78.30.32.73',
#  '81.61.40.199',
#  '2.153.80.222',
#  '89.6.69.22',
#  '79.158.152.164',
#  '93.176.171.227',
#  '46.6.8.24',
#  '87.218.217.13',
#  '88.12.102.11',
#  '213.195.113.240',
#  '109.205.134.28',
#  '92.59.209.151',
#  '77.226.217.179',
#  '46.253.226.179',
#  '81.61.73.125',
#  '2.137.33.199',
#  '[2',
#  '[2',
#  '83.55.54.179',
#  '83.39.37.207',
#  '90.162.126.41',
#  '83.39.94.29',
#  '88.1.136.102',
#  '144.178.135.74',
#  '37.15.63.3',
#  '83.58.154.203',
#  '81.184.215.161',
#  '90.163.172.139',
#  '146.158.193.203',
#  '89.35.142.168',
#  '93.176.161.169',
#  '212.14.101.8',
#  '62.83.157.147',
#  '81.40.210.166',
#  '2.138.74.205',
#  '87.222.235.33',
#  '81.184.168.238',
#  '2.152.78.124',
#  '83.33.232.62',
#  '84.39.176.10',
#  '2.138.174.158',
#  '90.170.20.2',
#  '88.12.34.111',
#  '46.6.10.230',
#  '85.58.120.201']
# 50

# %%
# User Agent
user_agent = []


for n in range(1,len(text)):
    user_agent.append(re.findall('Sa.+\d',text[n])[0])

# %%
user_agent
len(user_agent)
# Out:
# ['Satoshi:0.21.1',
#  'Satoshi:22.0.0',
#  'Satoshi:0.21.1',
#  'Satoshi:22.0.0',
#  'Satoshi:0.21.0',
#  'Satoshi:22.0.0',
#  'Satoshi:22.0.0',
#  'Satoshi:22.0.0',
#  'Satoshi:0.19.1',
#  'Satoshi:22.0.0',
#  'Satoshi:0.21.1',
#  'Satoshi:22.0.0',
#  'Satoshi:0.21.1',
#  'Satoshi:22.0.0',
#  'Satoshi:22.0.0',
#  'Satoshi:0.21.1',
#  'Satoshi:22.0.0',
#  'Satoshi:0.21.1',
#  'Satoshi:22.0.0',
#  'Satoshi:22.0.0',
#  'Satoshi:22.0.0',
#  'Satoshi:22.0.0',
#  'Satoshi:0.21.0',
#  'Satoshi:0.21.1',
#  'Satoshi:22.0.0',
#  'Satoshi:22.0.0',
#  'Satoshi:22.0.0',
#  'Satoshi:0.21.2',
#  'Satoshi:22.0.0',
#  'Satoshi:0.21.1',
#  'Satoshi:22.0.0',
#  'Satoshi:0.21.1',
#  'Satoshi:0.21.1',
#  'Satoshi:0.21.1',
#  'Satoshi:0.21.1',
#  'Satoshi:22.0.0',
#  'Satoshi:0.21.1',
#  'Satoshi:0.20.1',
#  'Satoshi:22.0.0',
#  'Satoshi:0.21.1',
#  'Satoshi:0.21.1',
#  'Satoshi:0.21.1',
#  'Satoshi:22.0.0',
#  'Satoshi:0.20.0',
#  'Satoshi:0.21.1',
#  'Satoshi:22.0.0',
#  'Satoshi:0.21.1',
#  'Satoshi:0.21.1',
#  'Satoshi:22.0.0',
#  'Satoshi:22.0.0']
# 50

# %%
# Height
height = []


for n in range(1,len(text)):
    height.append(re.findall('\d{5}', text[1])[0])

# %%
height
len(height)
# Out:
# ['70973',
#  '70973',
#  '70973',
#  '70973',
#  '70973',
#  '70973',
#  '70973',
#  '70973',
#  '70973',
#  '70973',
#  '70973',
#  '70973',
#  '70973',
#  '70973',
#  '70973',
#  '70973',
#  '70973',
#  '70973',
#  '70973',
#  '70973',
#  '70973',
#  '70973',
#  '70973',
#  '70973',
#  '70973',
#  '70973',
#  '70973',
#  '70973',
#  '70973',
#  '70973',
#  '70973',
#  '70973',
#  '70973',
#  '70973',
#  '70973',
#  '70973',
#  '70973',
#  '70973',
#  '70973',
#  '70973',
#  '70973',
#  '70973',
#  '70973',
#  '70973',
#  '70973',
#  '70973',
#  '70973',
#  '70973',
#  '70973',
#  '70973']
# 50

# %%
# Location
location = []


for n in range(1,len(text)):
    location.append(re.findall('\w+, Sp.+', text[n])[1])

# %%
location[1]
# Out:
# 'Madrid, SpainEurope/Madrid'

# %%
location
# Out:
# ['Madrid, SpainEurope/Madrid',
#  'Madrid, SpainEurope/Madrid',
#  'Sueca, SpainEurope/Madrid',
#  'Boceguillas, SpainEurope/Madrid',
#  'Málaga, SpainEurope/Madrid',
#  'Aguadulce, SpainEurope/Madrid',
#  'Madrid, SpainEurope/Madrid',
#  'Madrid, SpainEurope/Madrid',
#  'Viladecans, SpainEurope/Madrid',
#  'Vigo, SpainEurope/Madrid',
#  'Lleida, SpainEurope/Madrid',
#  'Usagre, SpainEurope/Madrid',
#  'Alameda, SpainEurope/Madrid',
#  'Albacete, SpainEurope/Madrid',
#  'Barcelona, SpainEurope/Madrid',
#  'Madrid, SpainEurope/Madrid',
#  'Armilla, SpainEurope/Madrid',
#  'Barcelona, SpainEurope/Madrid',
#  'Baena, SpainEurope/Madrid',
#  'Canaria, SpainAtlantic/Canary',
#  'Madrid, SpainEurope/Madrid',
#  'Madrid, SpainEurope/Madrid',
#  'Madrid, SpainEurope/Madrid',
#  'Chauchina, SpainEurope/Madrid',
#  'Cáceres, SpainEurope/Madrid',
#  'Valladolid, SpainEurope/Madrid',
#  'Madrid, SpainEurope/Madrid',
#  'Cantos, SpainEurope/Madrid',
#  'Fulgencio, SpainEurope/Madrid',
#  'Vallès, SpainEurope/Madrid',
#  'Canaria, SpainAtlantic/Canary',
#  'Pamplona, SpainEurope/Madrid',
#  'Murcia, SpainEurope/Madrid',
#  'Madrid, SpainEurope/Madrid',
#  'Cordova, SpainEurope/Madrid',
#  'Barcelona, SpainEurope/Madrid',
#  'Bilbao, SpainEurope/Madrid',
#  'Marbella, SpainEurope/Madrid',
#  'Madrid, SpainEurope/Madrid',
#  'Tacoronte, SpainAtlantic/Canary',
#  'Candas, SpainEurope/Madrid',
#  'Atarrabia, SpainEurope/Madrid',
#  'Barcelona, SpainEurope/Madrid',
#  'Madrid, SpainEurope/Madrid',
#  'Amorebieta, SpainEurope/Madrid',
#  'Pamplona, SpainEurope/Madrid',
#  'Blanques, SpainEurope/Madrid',
#  'Madrid, SpainEurope/Madrid',
#  'Jalon, SpainEurope/Madrid',
#  'Casabermeja, SpainEurope/Madrid']

# %%
text[2]
# Out:
# '\n\n83.39.95.241:8333\n241.red-83-39-95.dynamicip.rima-tde.net\n\nSince 6\xa0minutes ago\n/Satoshi:22.0.0/\nNODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)\n709736\nMadrid, Spain\nEurope/Madrid\n\nTelefonica De Espana\nAS3352\n\n83.39.95.241:8333241.red-83-39-95.dynamicip.rima-tde.netSince 6\xa0minutes ago\n/Satoshi:22.0.0/ (70016)NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)\n709736\nMadrid, SpainEurope/Madrid\nTelefonica De EspanaAS3352\n'

# %%
re.findall('\w+, Sp.+', text[5])[1]
# Out:
# 'Málaga, SpainEurope/Madrid'

# %%
re.findall('\w+, Sp.+', text[10])
# Out:
# ['Vigo, Spain', 'Vigo, SpainEurope/Madrid']

# %%
re.search(r'\d', text[3][2:17])
# Out:
# <regex.Match object; span=(0, 1), match='4'>

# %%
end_ip in text[3][2:17]
# Out:
# True

# %%
re.findall('\d+[.]\d+[.]\d+[.]\d+', text[3])
# Out:
# ['46.26.88.52', '46.26.88.52']

# %%
re.findall('[\d[.]+', text[3])[0]
# Out:
# '46.26.88.52'

# %%
text[3]
# Out:
# '\n\n46.26.88.52:8333\nstatic-52-88-26-46.ipcom.comunitel.net\n\nSince 43\xa0minutes ago\n/Satoshi:0.21.1/\nNODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)\n709593\nSueca, Spain\nEurope/Madrid\n\nVodafone Spain\nAS12430\n\n46.26.88.52:8333static-52-88-26-46.ipcom.comunitel.netSince 43\xa0minutes ago\n/Satoshi:0.21.1/ (70016)NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)\n709593\nSueca, SpainEurope/Madrid\nVodafone SpainAS12430\n'

# %%
ip_addr
# Out:
# ['188.127.182.204',
#  '78.30.32.73:833',
#  '46.26.88.52:833',
#  '47.63.18.131:83',
#  '2.153.80.222:83',
#  '93.176.171.227:',
#  '83.39.94.29:833',
#  '176.85.239.251:',
#  '81.61.40.199:83',
#  '88.1.136.102:83',
#  '144.178.135.74:',
#  '185.153.165.202',
#  '185.194.25.23:8',
#  '88.17.132.215:8',
#  '78.30.38.160:83',
#  '88.12.102.11:83',
#  '37.15.63.3:8333',
#  '2.139.120.47:83',
#  '88.1.90.75:8333',
#  '77.226.217.179:',
#  '83.58.154.203:8',
#  '83.50.222.219:8',
#  '81.184.215.161:',
#  '213.195.113.240',
#  '212.169.193.111',
#  '[2a0c:5a80:1e08',
#  '90.163.172.139:',
#  '37.132.88.72:83',
#  '146.158.193.203',
#  '89.35.142.168:8',
#  '93.176.161.169:',
#  '212.14.101.8:83',
#  '62.83.157.147:8',
#  '81.40.210.166:8',
#  '2.138.74.205:83',
#  '87.222.235.33:8',
#  '81.184.168.238:',
#  '83.39.37.207:83',
#  '2.152.78.124:83',
#  '83.33.232.62:83',
#  '84.39.176.10:83',
#  '2.138.174.158:8',
#  '90.170.20.2:833',
#  '88.12.34.111:83',
#  '46.6.10.230:833',
#  '85.58.120.201:8',
#  '79.147.121.95:8',
#  '185.49.169.118:',
#  '185.49.169.139:',
#  '46.8.171.139:83']

# %%
text[50][2:17]
# Out:
# '46.8.171.139:83'

# %%
text[2]
# Out:
# '\n\n188.127.182.204:8333\n\nSince 18\xa0minutes ago\n/Satoshi:0.21.1(FutureBit-Apollo-Node)/\nNODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)\n709593\nMadrid, Spain\nEurope/Madrid\n\nXtra Telecom S.A.\nAS15704\n\n188.127.182.204:8333Since 18\xa0minutes ago\n/Satoshi:0.21.1(FutureBit-Apollo-Node)/ (70016)NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)\n709593\nMadrid, SpainEurope/Madrid\nXtra Telecom S.A.AS15704\n'

# %%
text[3]
# Out:
# '\n\n46.26.88.52:8333\nstatic-52-88-26-46.ipcom.comunitel.net\n\nSince 43\xa0minutes ago\n/Satoshi:0.21.1/\nNODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)\n709593\nSueca, Spain\nEurope/Madrid\n\nVodafone Spain\nAS12430\n\n46.26.88.52:8333static-52-88-26-46.ipcom.comunitel.netSince 43\xa0minutes ago\n/Satoshi:0.21.1/ (70016)NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)\n709593\nSueca, SpainEurope/Madrid\nVodafone SpainAS12430\n'

# %%
text[4]
# Out:
# '\n\n47.63.18.131:8333\n47-63-18-131.red-acceso.airtel.net\n\nSince 50\xa0minutes ago\n/Satoshi:0.19.1/\nNODE_WITNESS, NODE_NETWORK_LIMITED (1032)\n709593\nBlanes, Spain\nEurope/Madrid\n\nVodafone Spain\nAS12430\n\n47.63.18.131:833347-63-18-131.red-acceso.airtel.netSince 50\xa0minutes ago\n/Satoshi:0.19.1/ (70015)NODE_WITNESS, NODE_NETWORK_LIMITED (1032)\n709593\nBlanes, SpainEurope/Madrid\nVodafone SpainAS12430\n'

# %%
text[50]
# Out:
# '\n\n46.8.171.139:8333\n\nSince 5\xa0days, 6\xa0hours ago\n/Satoshi:0.21.1/\nNODE_WITNESS, NODE_NETWORK_LIMITED (1032)\n709593\nMarbella, Spain\nEurope/Madrid\n\nOlivenet Network S.L.\nAS201746\n\n46.8.171.139:8333Since 5\xa0days, 6\xa0hours ago\n/Satoshi:0.21.1/ (70016)NODE_WITNESS, NODE_NETWORK_LIMITED (1032)\n709593\nMarbella, SpainEurope/Madrid\nOlivenet Network S.L.AS201746\n'

# %%
# Saving all addresses in an empty list 
ip_addresses= [] 

for i in table: 
    abused_addresses.append(i.get_text()) abused_addresses

# %%
# Looping thru all the elements of a single page
# Out:
# NODE
# ADDRESS
# USER AGENT
# HEIGHT
# LOCATION
# NETWORK
#
#
#
# 78.30.32.73:8333
# static.masmovil.com
#
# Since 5 minutes ago
# /Satoshi:22.0.0/
# NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709593
# Aguadulce, Spain
# Europe/Madrid
#
# Xtra Telecom S.A.
# AS15704
#
# 78.30.32.73:8333static.masmovil.comSince 5 minutes ago
# /Satoshi:22.0.0/ (70016)NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709593
# Aguadulce, SpainEurope/Madrid
# Xtra Telecom S.A.AS15704
#
#
#
# 188.127.182.204:8333
#
# Since 12 minutes ago
# /Satoshi:0.21.1(FutureBit-Apollo-Node)/
# NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709593
# Madrid, Spain
# Europe/Madrid
#
# Xtra Telecom S.A.
# AS15704
#
# 188.127.182.204:8333Since 12 minutes ago
# /Satoshi:0.21.1(FutureBit-Apollo-Node)/ (70016)NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709593
# Madrid, SpainEurope/Madrid
# Xtra Telecom S.A.AS15704
#
#
#
# 46.26.88.52:8333
# static-52-88-26-46.ipcom.comunitel.net
#
# Since 12 minutes ago
# /Satoshi:0.21.1/
# NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709593
# Sueca, Spain
# Europe/Madrid
#
# Vodafone Spain
# AS12430
#
# 46.26.88.52:8333static-52-88-26-46.ipcom.comunitel.netSince 12 minutes ago
# /Satoshi:0.21.1/ (70016)NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709593
# Sueca, SpainEurope/Madrid
# Vodafone SpainAS12430
#
#
#
# 47.63.18.131:8333
# 47-63-18-131.red-acceso.airtel.net
#
# Since 18 minutes ago
# /Satoshi:0.19.1/
# NODE_WITNESS, NODE_NETWORK_LIMITED (1032)
# 709591
# Blanes, Spain
# Europe/Madrid
#
# Vodafone Spain
# AS12430
#
# 47.63.18.131:833347-63-18-131.red-acceso.airtel.netSince 18 minutes ago
# /Satoshi:0.19.1/ (70015)NODE_WITNESS, NODE_NETWORK_LIMITED (1032)
# 709591
# Blanes, SpainEurope/Madrid
# Vodafone SpainAS12430
#
#
#
# 2.153.80.222:8333
# 2.153.80.222.dyn.user.ono.com
#
# Since 19 minutes ago
# /Satoshi:22.0.0/
# NODE_NETWORK, NODE_BLOOM, NODE_WITNESS, NODE_NETWORK_LIMITED, NODE_COMPACT_FILTERS (1101)
# 709591
# Madrid, Spain
# Europe/Madrid
#
# Vodafone Spain
# AS12430
#
# 2.153.80.222:83332.153.80.222.dyn.user.ono.comSince 19 minutes ago
# /Satoshi:22.0.0/ (70016)NODE_NETWORK, NODE_BLOOM, NODE_WITNESS, NODE_NETWORK_LIMITED, NODE_COMPACT_FILTERS (1101)
# 709591
# Madrid, SpainEurope/Madrid
# Vodafone SpainAS12430
#
#
#
# 93.176.171.227:8333
# static.masmovil.com
#
# Since 43 minutes ago
# /Satoshi:0.21.1/
# NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709591
# Lleida, Spain
# Europe/Madrid
#
# Xtra Telecom S.A.
# AS15704
#
# 93.176.171.227:8333static.masmovil.comSince 43 minutes ago
# /Satoshi:0.21.1/ (70016)NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709591
# Lleida, SpainEurope/Madrid
# Xtra Telecom S.A.AS15704
#
#
#
# 83.39.94.29:8333
# 29.red-83-39-94.dynamicip.rima-tde.net
#
# Since 50 minutes ago
# /Satoshi:22.0.0/
# NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709593
# Madrid, Spain
# Europe/Madrid
#
# Telefonica De Espana
# AS3352
#
# 83.39.94.29:833329.red-83-39-94.dynamicip.rima-tde.netSince 50 minutes ago
# /Satoshi:22.0.0/ (70016)NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709593
# Madrid, SpainEurope/Madrid
# Telefonica De EspanaAS3352
#
#
#
# 176.85.239.251:8333
# 251.red-176-85-239.dynamicip.rima-tde.net
#
# Since 50 minutes ago
# /Satoshi:22.0.0/
# NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709591
# Boceguillas, Spain
# Europe/Madrid
#
# Telefonica De Espana
# AS3352
#
# 176.85.239.251:8333251.red-176-85-239.dynamicip.rima-tde.netSince 50 minutes ago
# /Satoshi:22.0.0/ (70016)NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709591
# Boceguillas, SpainEurope/Madrid
# Telefonica De EspanaAS3352
#
#
#
# 81.61.40.199:8333
# 81.61.40.199.dyn.user.ono.com
#
# Since an hour ago
# /Satoshi:22.0.0/
# NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709593
# Madrid, Spain
# Europe/Madrid
#
# Vodafone Ono, S.A.
# AS6739
#
# 81.61.40.199:833381.61.40.199.dyn.user.ono.comSince an hour ago
# /Satoshi:22.0.0/ (70016)NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709593
# Madrid, SpainEurope/Madrid
# Vodafone Ono, S.A.AS6739
#
#
#
# 88.1.136.102:8333
# 102.red-88-1-136.dynamicip.rima-tde.net
#
# Since an hour ago
# /Satoshi:0.21.2/
# NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709591
# Tres Cantos, Spain
# Europe/Madrid
#
# Telefonica De Espana
# AS3352
#
# 88.1.136.102:8333102.red-88-1-136.dynamicip.rima-tde.netSince an hour ago
# /Satoshi:0.21.2/ (70016)NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709591
# Tres Cantos, SpainEurope/Madrid
# Telefonica De EspanaAS3352
#
#
#
# 144.178.135.74:8333
# static.masmovil.com
#
# Since an hour ago
# /Satoshi:22.0.0/
# NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709591
# San Fulgencio, Spain
# Europe/Madrid
#
# Xtra Telecom S.A.
# AS15704
#
# 144.178.135.74:8333static.masmovil.comSince an hour ago
# /Satoshi:22.0.0/ (70016)NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709591
# San Fulgencio, SpainEurope/Madrid
# Xtra Telecom S.A.AS15704
#
#
#
# 185.153.165.202:8333
#
# Since 2 hours ago
# /Satoshi:0.21.0/
# NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709591
# Málaga, Spain
# Europe/Madrid
#
# Xtra Telecom S.A.
# AS15704
#
# 185.153.165.202:8333Since 2 hours ago
# /Satoshi:0.21.0/ (70016)NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709591
# Málaga, SpainEurope/Madrid
# Xtra Telecom S.A.AS15704
#
#
#
# 185.194.25.23:8333
# 23.25.194.185.dyn.akiwifi.com
#
# Since 2 hours ago
# /Satoshi:0.20.1/
# NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709593
# El Espinar, Spain
# Europe/Madrid
#
# Nostravant S.L.L.
# AS201453
#
# 185.194.25.23:833323.25.194.185.dyn.akiwifi.comSince 2 hours ago
# /Satoshi:0.20.1/ (70015)NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709593
# El Espinar, SpainEurope/Madrid
# Nostravant S.L.L.AS201453
#
#
#
# 88.17.132.215:8333
# 215.red-88-17-132.dynamicip.rima-tde.net
#
# Since 4 hours ago
# /Satoshi:0.20.0/
# NODE_WITNESS, NODE_NETWORK_LIMITED (1032)
# 709593
# San Cristóbal de La Laguna, Spain
# Atlantic/Canary
#
# Telefonica De Espana
# AS3352
#
# 88.17.132.215:8333215.red-88-17-132.dynamicip.rima-tde.netSince 4 hours ago
# /Satoshi:0.20.0/ (70015)NODE_WITNESS, NODE_NETWORK_LIMITED (1032)
# 709593
# San Cristóbal de La Laguna, SpainAtlantic/Canary
# Telefonica De EspanaAS3352
#
#
#
# 78.30.38.160:8333
# static.masmovil.com
#
# Since 5 hours ago
# /Satoshi:22.0.0/
# NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709593
# Las Palmas de Gran Canaria, Spain
# Atlantic/Canary
#
# Xtra Telecom S.A.
# AS15704
#
# 78.30.38.160:8333static.masmovil.comSince 5 hours ago
# /Satoshi:22.0.0/ (70016)NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709593
# Las Palmas de Gran Canaria, SpainAtlantic/Canary
# Xtra Telecom S.A.AS15704
#
#
#
# 88.12.102.11:8333
# 11.red-88-12-102.dynamicip.rima-tde.net
#
# Since 6 hours ago
# /Satoshi:22.0.0/
# NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709593
# Albacete, Spain
# Europe/Madrid
#
# Telefonica De Espana
# AS3352
#
# 88.12.102.11:833311.red-88-12-102.dynamicip.rima-tde.netSince 6 hours ago
# /Satoshi:22.0.0/ (70016)NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709593
# Albacete, SpainEurope/Madrid
# Telefonica De EspanaAS3352
#
#
#
# 37.15.63.3:8333
# 3.63.15.37.dynamic.jazztel.es
#
# Since 8 hours ago
# /Satoshi:0.21.1/
# NODE_NETWORK, NODE_BLOOM, NODE_WITNESS, NODE_NETWORK_LIMITED (1037)
# 709591
# Sant Cugat del Vallès, Spain
# Europe/Madrid
#
# Orange Espagne SA
# AS12479
#
# 37.15.63.3:83333.63.15.37.dynamic.jazztel.esSince 8 hours ago
# /Satoshi:0.21.1/ (70016)NODE_NETWORK, NODE_BLOOM, NODE_WITNESS, NODE_NETWORK_LIMITED (1037)
# 709591
# Sant Cugat del Vallès, SpainEurope/Madrid
# Orange Espagne SAAS12479
#
#
#
# 2.139.120.47:8333
# 47.red-2-139-120.dynamicip.rima-tde.net
#
# Since 9 hours ago
# /Satoshi:0.21.2/
# NODE_NETWORK, NODE_BLOOM, NODE_WITNESS, NODE_NETWORK_LIMITED (1037)
# 709592
# Muro del Alcoy, Spain
# Europe/Madrid
#
# Telefonica De Espana
# AS3352
#
# 2.139.120.47:833347.red-2-139-120.dynamicip.rima-tde.netSince 9 hours ago
# /Satoshi:0.21.2/ (70016)NODE_NETWORK, NODE_BLOOM, NODE_WITNESS, NODE_NETWORK_LIMITED (1037)
# 709592
# Muro del Alcoy, SpainEurope/Madrid
# Telefonica De EspanaAS3352
#
#
#
# 88.1.90.75:8333
# 75.red-88-1-90.dynamicip.rima-tde.net
#
# Since 9 hours ago
# /Satoshi:22.0.0/
# NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 503763
# Girona, Spain
# Europe/Madrid
#
# Telefonica De Espana
# AS3352
#
# 88.1.90.75:833375.red-88-1-90.dynamicip.rima-tde.netSince 9 hours ago
# /Satoshi:22.0.0/ (70016)NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 503763
# Girona, SpainEurope/Madrid
# Telefonica De EspanaAS3352
#
#
#
# 77.226.217.179:8333
# static-179-217-226-77.ipcom.comunitel.net
#
# Since 11 hours ago
# /Satoshi:0.21.1/
# NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709593
# Barcelona, Spain
# Europe/Madrid
#
# Vodafone Spain
# AS12430
#
# 77.226.217.179:8333static-179-217-226-77.ipcom.comunitel.netSince 11 hours ago
# /Satoshi:0.21.1/ (70016)NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709593
# Barcelona, SpainEurope/Madrid
# Vodafone SpainAS12430
#
#
#
# 83.58.154.203:8333
# 203.red-83-58-154.dynamicip.rima-tde.net
#
# Since 12 hours ago
# /Satoshi:22.0.0/
# NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709592
# Las Palmas de Gran Canaria, Spain
# Atlantic/Canary
#
# Telefonica De Espana
# AS3352
#
# 83.58.154.203:8333203.red-83-58-154.dynamicip.rima-tde.netSince 12 hours ago
# /Satoshi:22.0.0/ (70016)NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709592
# Las Palmas de Gran Canaria, SpainAtlantic/Canary
# Telefonica De EspanaAS3352
#
#
#
# 83.50.222.219:8333
# 219.red-83-50-222.dynamicip.rima-tde.net
#
# Since 13 hours ago
# /Satoshi:0.21.1/
# NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709593
# Albolote, Spain
# Europe/Madrid
#
# Telefonica De Espana
# AS3352
#
# 83.50.222.219:8333219.red-83-50-222.dynamicip.rima-tde.netSince 13 hours ago
# /Satoshi:0.21.1/ (70016)NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709593
# Albolote, SpainEurope/Madrid
# Telefonica De EspanaAS3352
#
#
#
# 109.205.134.28:8333
# 28.pool109-205-134.dynamic.orange.es
#
# Since 13 hours ago
# /Satoshi:0.21.1/
# NODE_WITNESS, NODE_NETWORK_LIMITED (1032)
# 709593
# Madrid, Spain
# Europe/Madrid
#
# Orange Espagne SA
# AS12479
#
# 109.205.134.28:833328.pool109-205-134.dynamic.orange.esSince 13 hours ago
# /Satoshi:0.21.1/ (70016)NODE_WITNESS, NODE_NETWORK_LIMITED (1032)
# 709593
# Madrid, SpainEurope/Madrid
# Orange Espagne SAAS12479
#
#
#
# 81.184.215.161:8333
# 81.184.215.161.dyn.user.ono.com
#
# Since 15 hours ago
# /Satoshi:0.21.1/
# NODE_WITNESS, NODE_NETWORK_LIMITED (1032)
# 709593
# Pamplona, Spain
# Europe/Madrid
#
# Vodafone Ono, S.A.
# AS6739
#
# 81.184.215.161:833381.184.215.161.dyn.user.ono.comSince 15 hours ago
# /Satoshi:0.21.1/ (70016)NODE_WITNESS, NODE_NETWORK_LIMITED (1032)
# 709593
# Pamplona, SpainEurope/Madrid
# Vodafone Ono, S.A.AS6739
#
#
#
# 213.195.113.240:8333
#
# Since 16 hours ago
# /Satoshi:22.0.0/
# NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709593
# Barcelona, Spain
# Europe/Madrid
#
# Xtra Telecom S.A.
# AS15704
#
# 213.195.113.240:8333Since 16 hours ago
# /Satoshi:22.0.0/ (70016)NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709593
# Barcelona, SpainEurope/Madrid
# Xtra Telecom S.A.AS15704
#
#
#
# 212.169.193.111:8333
#
# Since 17 hours ago
# /Satoshi:0.8.5/
# NODE_NETWORK (1)
# 409221
# Seville, Spain
# Europe/Madrid
#
# Orange Espagne SA
# AS12479
#
# 212.169.193.111:8333Since 17 hours ago
# /Satoshi:0.8.5/ (70001)NODE_NETWORK (1)
# 409221
# Seville, SpainEurope/Madrid
# Orange Espagne SAAS12479
#
#
#
# [2a0c:5a80:1e08:a000:a494:3ead:bf5e:d520]:8333
#
# Since 18 hours ago
# /Satoshi:0.21.0/
# NODE_WITNESS, NODE_NETWORK_LIMITED (1032)
# 709592
# Madrid, Spain
# Europe/Madrid
#
# Digi Spain Telecom S.l.u.
# AS57269
#
# [2a0c:5a80:1e08:a000:a494:3ead:bf5e:d520]:8333Since 18 hours ago
# /Satoshi:0.21.0/ (70016)NODE_WITNESS, NODE_NETWORK_LIMITED (1032)
# 709592
# Madrid, SpainEurope/Madrid
# Digi Spain Telecom S.l.u.AS57269
#
#
#
# 90.163.172.139:8333
#
# Since 20 hours ago
# /Satoshi:0.21.1/
# NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709591
# Murcia, Spain
# Europe/Madrid
#
# Orange Espagne SA
# AS12479
#
# 90.163.172.139:8333Since 20 hours ago
# /Satoshi:0.21.1/ (70016)NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709591
# Murcia, SpainEurope/Madrid
# Orange Espagne SAAS12479
#
#
#
# 37.132.88.72:8333
# 72.88.132.37.dynamic.jazztel.es
#
# Since 1 day ago
# /Satoshi:22.0.0/
# NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 707826
# El Arahal, Spain
# Europe/Madrid
#
# Orange Espagne SA
# AS12479
#
# 37.132.88.72:833372.88.132.37.dynamic.jazztel.esSince 1 day ago
# /Satoshi:22.0.0/ (70016)NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 707826
# El Arahal, SpainEurope/Madrid
# Orange Espagne SAAS12479
#
#
#
# 146.158.193.203:8333
# sergioir.ddns.jazztel.es
#
# Since 1 day, 4 hours ago
# /Satoshi:0.21.1/
# NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709591
# Madrid, Spain
# Europe/Madrid
#
# Orange Espagne SA
# AS12479
#
# 146.158.193.203:8333sergioir.ddns.jazztel.esSince 1 day, 4 hours ago
# /Satoshi:0.21.1/ (70016)NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709591
# Madrid, SpainEurope/Madrid
# Orange Espagne SAAS12479
#
#
#
# 89.35.142.168:8333
#
# Since 1 day, 6 hours ago
# /Satoshi:0.21.1/
# NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709593
# Cordova, Spain
# Europe/Madrid
#
# Procono S.A.
# AS34977
#
# 89.35.142.168:8333Since 1 day, 6 hours ago
# /Satoshi:0.21.1/ (70016)NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709593
# Cordova, SpainEurope/Madrid
# Procono S.A.AS34977
#
#
#
# 93.176.161.169:8333
# static.masmovil.com
#
# Since 1 day, 12 hours ago
# /Satoshi:22.0.0/
# NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709593
# Barcelona, Spain
# Europe/Madrid
#
# Xtra Telecom S.A.
# AS15704
#
# 93.176.161.169:8333static.masmovil.comSince 1 day, 12 hours ago
# /Satoshi:22.0.0/ (70016)NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709593
# Barcelona, SpainEurope/Madrid
# Xtra Telecom S.A.AS15704
#
#
#
# 212.14.101.8:8333
# static.8.101.14.212.ibercom.com
#
# Since 1 day, 12 hours ago
# /Satoshi:0.21.1/
# NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709593
# Bilbao, Spain
# Europe/Madrid
#
# Xtra Telecom S.A.
# AS15704
#
# 212.14.101.8:8333static.8.101.14.212.ibercom.comSince 1 day, 12 hours ago
# /Satoshi:0.21.1/ (70016)NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709593
# Bilbao, SpainEurope/Madrid
# Xtra Telecom S.A.AS15704
#
#
#
# 62.83.157.147:8333
# 62.83.157.147.dyn.user.ono.com
#
# Since 2 days, 2 hours ago
# /Satoshi:0.20.1/
# NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709593
# Marbella, Spain
# Europe/Madrid
#
# Vodafone Spain
# AS12430
#
# 62.83.157.147:833362.83.157.147.dyn.user.ono.comSince 2 days, 2 hours ago
# /Satoshi:0.20.1/ (70015)NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709593
# Marbella, SpainEurope/Madrid
# Vodafone SpainAS12430
#
#
#
# 81.40.210.166:8333
# 166.red-81-40-210.staticip.rima-tde.net
#
# Since 2 days, 4 hours ago
# /Satoshi:22.0.0/
# NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709591
# Madrid, Spain
# Europe/Madrid
#
# Telefonica De Espana
# AS3352
#
# 81.40.210.166:8333166.red-81-40-210.staticip.rima-tde.netSince 2 days, 4 hours ago
# /Satoshi:22.0.0/ (70016)NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709591
# Madrid, SpainEurope/Madrid
# Telefonica De EspanaAS3352
#
#
#
# 2.138.74.205:8333
# 205.red-2-138-74.dynamicip.rima-tde.net
#
# Since 2 days, 6 hours ago
# /Satoshi:0.21.1/
# NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709591
# Tacoronte, Spain
# Atlantic/Canary
#
# Telefonica De Espana
# AS3352
#
# 2.138.74.205:8333205.red-2-138-74.dynamicip.rima-tde.netSince 2 days, 6 hours ago
# /Satoshi:0.21.1/ (70016)NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709591
# Tacoronte, SpainAtlantic/Canary
# Telefonica De EspanaAS3352
#
#
#
# 87.222.235.33:8333
# 33.235.222.87.dynamic.jazztel.es
#
# Since 2 days, 8 hours ago
# /Satoshi:0.21.1(FutureBit-Apollo-Node)/
# NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709587
# Candas, Spain
# Europe/Madrid
#
# Orange Espagne SA
# AS12479
#
# 87.222.235.33:833333.235.222.87.dynamic.jazztel.esSince 2 days, 8 hours ago
# /Satoshi:0.21.1(FutureBit-Apollo-Node)/ (70016)NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709587
# Candas, SpainEurope/Madrid
# Orange Espagne SAAS12479
#
#
#
# 81.184.168.238:8333
# 81.184.168.238.dyn.user.ono.com
#
# Since 2 days, 8 hours ago
# /Satoshi:0.21.1/
# NODE_WITNESS, NODE_NETWORK_LIMITED (1032)
# 709593
# Atarrabia, Spain
# Europe/Madrid
#
# Vodafone Ono, S.A.
# AS6739
#
# 81.184.168.238:833381.184.168.238.dyn.user.ono.comSince 2 days, 8 hours ago
# /Satoshi:0.21.1/ (70016)NODE_WITNESS, NODE_NETWORK_LIMITED (1032)
# 709593
# Atarrabia, SpainEurope/Madrid
# Vodafone Ono, S.A.AS6739
#
#
#
# 83.39.37.207:8333
# 207.red-83-39-37.dynamicip.rima-tde.net
#
# Since 2 days, 14 hours ago
# /Satoshi:22.0.0/
# NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709591
# Cáceres, Spain
# Europe/Madrid
#
# Telefonica De Espana
# AS3352
#
# 83.39.37.207:8333207.red-83-39-37.dynamicip.rima-tde.netSince 2 days, 14 hours ago
# /Satoshi:22.0.0/ (70016)NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709591
# Cáceres, SpainEurope/Madrid
# Telefonica De EspanaAS3352
#
#
#
# 2.152.78.124:8333
# 2.152.78.124.dyn.user.ono.com
#
# Since 2 days, 21 hours ago
# /Satoshi:22.0.0/
# NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709593
# Barcelona, Spain
# Europe/Madrid
#
# Vodafone Ono, S.A.
# AS6739
#
# 2.152.78.124:83332.152.78.124.dyn.user.ono.comSince 2 days, 21 hours ago
# /Satoshi:22.0.0/ (70016)NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709593
# Barcelona, SpainEurope/Madrid
# Vodafone Ono, S.A.AS6739
#
#
#
# 83.33.232.62:8333
# 62.red-83-33-232.dynamicip.rima-tde.net
#
# Since 2 days, 21 hours ago
# /Satoshi:0.20.0/
# NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709593
# Las Rozas de Madrid, Spain
# Europe/Madrid
#
# Telefonica De Espana
# AS3352
#
# 83.33.232.62:833362.red-83-33-232.dynamicip.rima-tde.netSince 2 days, 21 hours ago
# /Satoshi:0.20.0/ (70015)NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709593
# Las Rozas de Madrid, SpainEurope/Madrid
# Telefonica De EspanaAS3352
#
#
#
# 84.39.176.10:8333
# static.masmovil.com
#
# Since 2 days, 23 hours ago
# /Satoshi:0.21.1/
# NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709591
# Amorebieta, Spain
# Europe/Madrid
#
# Xtra Telecom S.A.
# AS15704
#
# 84.39.176.10:8333static.masmovil.comSince 2 days, 23 hours ago
# /Satoshi:0.21.1/ (70016)NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709591
# Amorebieta, SpainEurope/Madrid
# Xtra Telecom S.A.AS15704
#
#
#
# 2.138.174.158:8333
# 158.red-2-138-174.dynamicip.rima-tde.net
#
# Since 3 days, 5 hours ago
# /Satoshi:22.0.0/
# NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709592
# Pamplona, Spain
# Europe/Madrid
#
# Telefonica De Espana
# AS3352
#
# 2.138.174.158:8333158.red-2-138-174.dynamicip.rima-tde.netSince 3 days, 5 hours ago
# /Satoshi:22.0.0/ (70016)NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709592
# Pamplona, SpainEurope/Madrid
# Telefonica De EspanaAS3352
#
#
#
# 90.170.20.2:8333
#
# Since 3 days, 6 hours ago
# /Satoshi:0.21.1/
# NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709592
# Les Borges Blanques, Spain
# Europe/Madrid
#
# Orange Espagne SA
# AS12479
#
# 90.170.20.2:8333Since 3 days, 6 hours ago
# /Satoshi:0.21.1/ (70016)NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709592
# Les Borges Blanques, SpainEurope/Madrid
# Orange Espagne SAAS12479
#
#
#
# 88.12.34.111:8333
# 111.red-88-12-34.staticip.rima-tde.net
#
# Since 3 days, 7 hours ago
# /Satoshi:0.21.1/
# NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709593
# Madrid, Spain
# Europe/Madrid
#
# Telefonica De Espana
# AS3352
#
# 88.12.34.111:8333111.red-88-12-34.staticip.rima-tde.netSince 3 days, 7 hours ago
# /Satoshi:0.21.1/ (70016)NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709593
# Madrid, SpainEurope/Madrid
# Telefonica De EspanaAS3352
#
#
#
# 46.6.10.230:8333
#
# Since 3 days, 9 hours ago
# /Satoshi:22.0.0/
# NODE_NETWORK, NODE_BLOOM, NODE_WITNESS, NODE_NETWORK_LIMITED (1037)
# 709593
# Arcos de Jalon, Spain
# Europe/Madrid
#
# Xtra Telecom S.A.
# AS15704
#
# 46.6.10.230:8333Since 3 days, 9 hours ago
# /Satoshi:22.0.0/ (70016)NODE_NETWORK, NODE_BLOOM, NODE_WITNESS, NODE_NETWORK_LIMITED (1037)
# 709593
# Arcos de Jalon, SpainEurope/Madrid
# Xtra Telecom S.A.AS15704
#
#
#
# 85.58.120.201:8333
# 201.pool85-58-120.static.orange.es
#
# Since 3 days, 10 hours ago
# /Satoshi:22.0.0/
# NODE_NETWORK, NODE_BLOOM, NODE_WITNESS, NODE_NETWORK_LIMITED, NODE_COMPACT_FILTERS (1101)
# 709593
# Casabermeja, Spain
# Europe/Madrid
#
# Orange Espagne SA
# AS12479
#
# 85.58.120.201:8333201.pool85-58-120.static.orange.esSince 3 days, 10 hours ago
# /Satoshi:22.0.0/ (70016)NODE_NETWORK, NODE_BLOOM, NODE_WITNESS, NODE_NETWORK_LIMITED, NODE_COMPACT_FILTERS (1101)
# 709593
# Casabermeja, SpainEurope/Madrid
# Orange Espagne SAAS12479
#
#
#
# 79.147.121.95:8333
# 95.red-79-147-121.dynamicip.rima-tde.net
#
# Since 4 days, 13 hours ago
# /Satoshi:22.0.0/
# NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709593
# Avilés, Spain
# Europe/Madrid
#
# Telefonica De Espana
# AS3352
#
# 79.147.121.95:833395.red-79-147-121.dynamicip.rima-tde.netSince 4 days, 13 hours ago
# /Satoshi:22.0.0/ (70016)NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709593
# Avilés, SpainEurope/Madrid
# Telefonica De EspanaAS3352
#
#
#
# 185.49.169.118:8333
#
# Since 5 days ago
# /Satoshi:22.0.0/
# NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709592
# Marbella, Spain
# Europe/Madrid
#
# Olivenet Network S.L.
# AS201746
#
# 185.49.169.118:8333Since 5 days ago
# /Satoshi:22.0.0/ (70016)NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709592
# Marbella, SpainEurope/Madrid
# Olivenet Network S.L.AS201746
#
#
#
# 185.49.169.139:8333
#
# Since 5 days, 5 hours ago
# /Satoshi:0.21.1/
# NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709593
# Marbella, Spain
# Europe/Madrid
#
# Olivenet Network S.L.
# AS201746
#
# 185.49.169.139:8333Since 5 days, 5 hours ago
# /Satoshi:0.21.1/ (70016)NODE_NETWORK, NODE_WITNESS, NODE_NETWORK_LIMITED (1033)
# 709593
# Marbella, SpainEurope/Madrid
# Olivenet Network S.L.AS201746

# %%
# Creating the map and adding params
map = folium.Map(location=[41.38, 2.15], tiles='CartoDB dark_matter')

# Creating feature group
fg = folium.FeatureGroup(name='My map')
fg.add_child(folium.Marker(location= [41.35, 2.15], popup= 'This is a marker', icon= folium.Icon(color= 'pink')))

map.add_child(fg)

# map.save("filename.html")
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_c5de6e481b7e43faad8a0063a13aea17%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_c5de6e481b7e43faad8a0063a13aea17%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_c5de6e481b7e43faad8a0063a13aea17%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_c5de6e481b7e43faad8a0063a13aea17%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B41.38%2C%202.15%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20c ...

# %%
def spa(coordinates):
    ...
